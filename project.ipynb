# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
df=pd.read_csv('users.csv')

# %%
df.head()
# Out:
#    id firstName  lastName maidenName  age  gender  \
# 0   1     Emily   Johnson      Smith   29  female
# 1   2   Michael  Williams        NaN   36    male
# 2   3    Sophia     Brown        NaN   43  female
# 3   4     James     Davis        NaN   46    male
# 4   5      Emma    Miller    Johnson   31  female
#
#                               email             phone  username      password  \
# 0     emily.johnson@x.dummyjson.com  +81 965-431-3024    emilys    emilyspass
# 1  michael.williams@x.dummyjson.com  +49 258-627-6644  michaelw  michaelwpass
# 2      sophia.brown@x.dummyjson.com  +81 210-652-2785   sophiab   sophiabpass
# 3       james.davis@x.dummyjson.com  +49 614-958-9364    jamesd    jamesdpass
# 4       emma.miller@x.dummyjson.com  +91 759-776-1614     emmaj     emmajpass
#
#    ...                                            address         macAddress  \
# 0  ...  {'address': '626 Main Street', 'city': 'Phoeni...  47:fa:41:18:ec:eb
# ...

# %%
df.shape
# Out:
# (208, 28)

# %%
print(df.columns)
# Out:
# Index(['id', 'firstName', 'lastName', 'maidenName', 'age', 'gender', 'email',
#        'phone', 'username', 'password', 'birthDate', 'image', 'bloodGroup',
#        'height', 'weight', 'eyeColor', 'hair', 'ip', 'address', 'macAddress',
#        'university', 'bank', 'company', 'ein', 'ssn', 'userAgent', 'crypto',
#        'role'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id              int64
# firstName      object
# lastName       object
# maidenName     object
# age             int64
# gender         object
# email          object
# phone          object
# username       object
# password       object
# birthDate      object
# image          object
# bloodGroup     object
# height        float64
# weight        float64
# eyeColor       object
# hair           object
# ip             object
# address        object
# macAddress     object
# university     object
# bank           object
# company        object
# ein            object
# ssn            object
# userAgent      object
# crypto         object
# role           object
# dtype: object

# %%
df['birthDate'] = pd.to_datetime(df['birthDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          208 non-null    int64
#  1   firstName   208 non-null    object
#  2   lastName    208 non-null    object
#  3   maidenName  60 non-null     object
#  4   age         208 non-null    int64
#  5   gender      208 non-null    object
#  6   email       208 non-null    object
#  7   phone       208 non-null    object
#  8   username    208 non-null    object
#  9   password    208 non-null    object
#  10  birthDate   208 non-null    datetime64[ns]
#  11  image       208 non-null    object
#  12  bloodGroup  208 non-null    object
#  13  height      208 non-null    float64
#  14  weight      208 non-null    float64
#  15  eyeColor    208 non-null    object
#  16  hair        208 non-null    object
#  17  ip          208 non-null    object
#  18  address     208 non-null    object
# ...

# %%
df.describe()
# Out:
#                id         age                      birthDate      height  \
# count  208.000000  208.000000                            208  208.000000
# mean   104.500000   33.139423  1992-05-08 13:43:50.769230720  175.720240
# min      1.000000   23.000000            1979-01-26 00:00:00  150.250000
# 25%     52.750000   29.000000            1989-02-04 18:00:00  164.187500
# 50%    104.500000   32.000000            1993-06-25 00:00:00  177.430000
# 75%    156.250000   36.000000            1996-08-25 12:00:00  186.960000
# max    208.000000   46.000000            2002-04-20 00:00:00  199.810000
# std     60.188592    5.544269                            NaN   14.119984
#
#            weight
# count  208.000000
# mean    75.038606
# min     50.100000
# 25%     62.547500
# 50%     75.985000
# 75%     86.992500
# max     99.540000
# std     14.090775

# %%
df.describe(include=object).T
# Out:
#            count unique                                                top  \
# firstName    208    119                                              Lucas
# lastName     208    117                                              Perez
# maidenName    60     40                                              Adams
# gender       208      2                                             female
# email        208    208                      emily.johnson@x.dummyjson.com
# phone        208    208                                   +81 965-431-3024
# username     208    208                                             emilys
# password     208    208                                         emilyspass
# image        208    208              https://dummyjson.com/icon/emilys/128
# bloodGroup   208      8                                                 O-
# eyeColor     208      8                                              Brown
# ...

# %%
df.isna().sum()
# Out:
# id              0
# firstName       0
# lastName        0
# maidenName    148
# age             0
# gender          0
# email           0
# phone           0
# username        0
# password        0
# birthDate       0
# image           0
# bloodGroup      0
# height          0
# weight          0
# eyeColor        0
# hair            0
# ip              0
# address         0
# macAddress      0
# university      0
# bank            0
# company         0
# ein             0
# ssn             0
# userAgent       0
# crypto          0
# role            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
percent=df['maidenName'].isna().mean()*100
percent
# Out:
# 71.15384615384616

# %%
df.drop(columns=['id','maidenName'],inplace=True)

# %%
df['gender'].value_counts()
# Out:
# gender
# female    106
# male      102
# Name: count, dtype: int64

# %%
print(df['bloodGroup'].value_counts())
# Out:
# bloodGroup
# O-     31
# B-     31
# AB+    29
# AB-    29
# B+     25
# O+     22
# A+     21
# A-     20
# Name: count, dtype: int64

# %%
print(df['eyeColor'].value_counts())
# Out:
# eyeColor
# Brown     35
# Hazel     34
# Green     28
# Blue      24
# Gray      24
# Violet    22
# Red       21
# Amber     20
# Name: count, dtype: int64

# %%
def parse_address(addr_str):
    try:
        addr_dict = json.loads(addr_str.replace("'", "\""))  # fix single quotes to double
        return addr_dict.get('city', 'Unknown') 
    except:
        return 'Unknown'

df['city'] = df['address'].apply(parse_address)

# %%
df.head(5)
# Out:
#   firstName  lastName  age  gender                             email  \
# 0     Emily   Johnson   29  female     emily.johnson@x.dummyjson.com
# 1   Michael  Williams   36    male  michael.williams@x.dummyjson.com
# 2    Sophia     Brown   43  female      sophia.brown@x.dummyjson.com
# 3     James     Davis   46    male       james.davis@x.dummyjson.com
# 4      Emma    Miller   31  female       emma.miller@x.dummyjson.com
#
#               phone  username      password  birthDate  \
# 0  +81 965-431-3024    emilys    emilyspass 1996-05-30
# 1  +49 258-627-6644  michaelw  michaelwpass 1989-08-10
# 2  +81 210-652-2785   sophiab   sophiabpass 1982-11-06
# 3  +49 614-958-9364    jamesd    jamesdpass 1979-05-04
# 4  +91 759-776-1614     emmaj     emmajpass 1994-06-13
#
#                                      image  ...         macAddress  \
# 0    https://dummyjson.com/icon/emilys/128  ...  47:fa:41:18:ec:eb
# 1  https://dummyjson.com/icon/michaelw/128  ...  79:15:78:99:60:aa
# ...

# %%
df['city'].value_counts()
# Out:
# city
# Phoenix          17
# Dallas           15
# Jacksonville     14
# Los Angeles      14
# Seattle          12
# San Jose         11
# Charlotte        11
# Philadelphia     11
# Chicago          11
# Columbus         11
# New York         11
# San Diego        10
# Indianapolis     10
# Denver            8
# San Francisco     8
# Houston           7
# San Antonio       7
# Fort Worth        7
# Austin            7
# Washington        6
# Name: count, dtype: int64

# %%
def parse_address2(addr_str):
    try:
        addr_dict = json.loads(addr_str.replace("'", "\"")) 
        return addr_dict.get('country', 'Unknown') 
    except:
        return 'Unknown'

df['country'] = df['address'].apply(parse_address2)

# %%
df['country'].value_counts()
# Out:
# country
# United States    208
# Name: count, dtype: int64

# %%
def parse_address3(addr_str):
    try:
        addr_dict = json.loads(addr_str.replace("'", "\"")) 
        return addr_dict.get('state', 'Unknown') 
    except:
        return 'Unknown'

df['state'] = df['address'].apply(parse_address3)

# %%
df['state'].value_counts()
# Out:
# state
# Arkansas          10
# West Virginia      8
# New Hampshire      8
# Vermont            8
# Utah               8
# Mississippi        7
# Delaware           7
# Maryland           6
# Idaho              6
# Montana            6
# Tennessee          6
# Connecticut        5
# North Dakota       5
# Wisconsin          5
# Rhode Island       5
# South Carolina     5
# New Jersey         5
# Pennsylvania       5
# Alabama            5
# Minnesota          5
# Nevada             5
# Massachusetts      4
# Arizona            4
# South Dakota       4
# New York           4
# Illinois           4
# New Mexico         4
# Florida            4
# Wyoming            4
# Georgia            3
# Michigan           3
# Kansas             3
# North Carolina     3
# Colorado           3
# Oregon             3
# Indiana            3
# Missouri           3
# Louisiana          3
# Iowa               3
# Ohio               3
# Alaska             2
# Maine              2
# Texas              2
# ...

# %%
df['role'].value_counts()
# Out:
# role
# user         193
# moderator     10
# admin          5
# Name: count, dtype: int64

# %%
def parse_bank(bank_str):
    try:
        bank_dict = json.loads(bank_str.replace("'", "\"")) 
        return bank_dict.get('cardType', 'Unknown') 
    except:
        return 'Unknown'
    
df['cardType']=df['bank'].apply(parse_bank)

# %%
print('nuniques',df['cardType'].nunique())
print(df['cardType'].value_counts())
# Out:
# nuniques 7
# cardType
# Mastercard                   41
# Discover                     34
# American Express             29
# Visa                         29
# UnionPay                     27
# Diners Club International    26
# JCB                          22
# Name: count, dtype: int64

# %%
def parse_bank2(bank_str):
    try:
        bank_dict = json.loads(bank_str.replace("'", "\"")) 
        return bank_dict.get('currency', 'Unknown') 
    except:
        return 'Unknown'
    
df['currency']=df['bank'].apply(parse_bank2)

# %%
print('nuniques',df['currency'].nunique())
print(df['currency'].value_counts())
# Out:
# nuniques 10
# currency
# EUR    29
# CAD    26
# USD    25
# PKR    23
# AUD    22
# GBP    21
# JPY    18
# NZD    16
# CNY    14
# INR    14
# Name: count, dtype: int64

# %%
def parse_hair(hair_str):
    try:
        hair_dict = json.loads(hair_str.replace("'", "\"")) 
        return hair_dict.get('type', 'Unknown') 
    except:
        return 'Unknown'
    
df['hair_type']=df['hair'].apply(parse_hair)

# %%
print('nuniques',df['hair_type'].nunique())
print(df['hair_type'].value_counts())
# Out:
# nuniques 4
# hair_type
# Wavy        67
# Curly       55
# Straight    48
# Kinky       38
# Name: count, dtype: int64

# %%
def parse_company(company_str):
    try:
        company_dict = json.loads(company_str.replace("'", "\"")) 
        return company_dict.get('title', 'Unknown') 
    except:
        return 'Unknown'
    
df['job_title']=df['company'].apply(parse_company)

# %%
print('nuniques',df['job_title'].nunique())
print(df['job_title'].value_counts())
# Out:
# nuniques 27
# job_title
# Project Manager                 14
# Web Developer                   12
# Legal Counsel                   12
# Business Analyst                12
# Chief Financial Officer         11
# Database Administrator          11
# Support Specialist              10
# Developer                        9
# Chief Executive Officer          9
# Software Architect               9
# Sales Manager                    8
# Engineer                         8
# Chief Technology Officer         8
# Quality Assurance Engineer       7
# Technical Support Engineer       7
# Research Analyst                 7
# Software Engineer                6
# Chief Information Officer        6
# Marketing Manager                6
# Chief Operating Officer          6
# Data Scientist                   6
# Systems Analyst                  6
# Human Resources Manager          5
# Accountant                       4
# Product Manager                  4
# Data Analyst                     3
# ...

# %%
average_age = df['age'].mean()
print(f"Average age of users: {average_age:.2f}")
# Out:
# Average age of users: 33.14

# %%
sns.histplot(df['age'],
            color='teal',
            kde=True,
            edgecolor='black',
            alpha=0.8)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Students")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
data=df.groupby('gender')['age'].mean()
plt.figure(figsize=(5, 5))
plt.pie(data, 
        labels=['Female', 'Male'], 
        autopct='%1.1f%%', 
        colors=['#66b3ff', '#ff9999'],
        startangle=90)
plt.title('Average Age by Gender', fontsize=14)
plt.axis('equal')  
plt.show()

# %%
counts=df['gender'].value_counts()
plt.figure(figsize=(5,4))
plt.bar(counts.index,counts.values,color='teal', edgecolor='black')
plt.title('Gender Distribution', fontsize=14)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Number of Users', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
counts=df['cardType'].value_counts()
plt.figure(figsize=(8,4))
plt.bar(counts.index,counts.values,color='teal', edgecolor='black')
plt.title('Number of Users per cardtype', fontsize=14)
plt.xlabel('CardType', fontsize=10)
plt.ylabel('Number of Users', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.xticks(rotation=45) 
plt.show()

# %%
country_counts = df.groupby('city').size().reset_index(name='User_Count')

country_counts = country_counts.sort_values('User_Count', ascending=False)

print(country_counts.head(10))
# Out:
#             city  User_Count
# 13       Phoenix          17
# 4         Dallas          15
# 10   Los Angeles          14
# 9   Jacksonville          14
# 18       Seattle          12
# 2        Chicago          11
# 3       Columbus          11
# 17      San Jose          11
# 1      Charlotte          11
# 11      New York          11

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data=country_counts.head(10),
            x='city',          
            y='User_Count', 
            palette='viridis')
plt.title('Number of Users by Country (Top 10)', fontsize=15)
plt.ylabel('Number of Users', fontsize=10)
plt.xlabel('Country', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHMMED\AppData\Local\Temp\ipykernel_26548\3979480582.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=country_counts.head(10),

# %%
avg = df[['height','weight']].mean()
print(avg)
# Out:
# height    175.720240
# weight     75.038606
# dtype: float64

# %%
avg = df[['height','weight']].mean()
plt.bar(avg.index, avg.values,
        color=['skyblue','salmon'],
        edgecolor='black',
        alpha=0.8)
plt.title("Average Height and Weight Overall")
plt.xlabel("Feature")
plt.ylabel("Average Value")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.regplot(data=df, x='age', y='height')
plt.title("Relationship between Age and Height")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.regplot(data=df, x='age', y='weight')
plt.title("Relationship between Age and Weight")
plt.show()

# %%
corr = df[['age','height','weight']].corr()
sns.heatmap(corr, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x='city', hue='hair_type')
plt.title("city counts by hair_type")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x='cardType', hue='currency')
plt.title("cardType counts by currency")
plt.xticks(rotation=45)
plt.show()

# %%
df.to_csv('users1.csv', index=False)
print("Saved to users1.xlsx")
# Out:
# Saved to users1.xlsx
